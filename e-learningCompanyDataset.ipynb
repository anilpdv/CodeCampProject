# %% [markdown]
# # working on e-learning company Dataset

# %% [markdown]
# #### The goal of the analysis is to find out which product to advertise on and to invest in marketing

# %%
#loading th libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the file
df = pd.read_csv('2017-fCC-New-Coders-Survey-Data.csv')

# %%
#no of rows and columns
print('number of rows: '+str(df.shape[0])+' are in the dataset')
print('number of columns:'+str(df.shape[1])+' are in the dataset')
# Out:
# number of rows: 2882 are in the dataset
# number of columns:136 are in the dataset

# %%
#first five rows of the dataset
df.head(3)
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber       CityPopulation  \
# 0                NaN             NaN  more than 1 million
# 1                NaN             NaN    less than 100,000
# 2                NaN             NaN  more than 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls         ...           \
# 0                   NaN                   NaN         ...
# 1                   NaN                   NaN         ...
# 2                   NaN                   NaN         ...
#
#    YouTubeFCC  YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0         NaN                    NaN               NaN               NaN
# ...

# %%
df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls',
#        ...
#        'YouTubeFCC', 'YouTubeFunFunFunction', 'YouTubeGoogleDev',
#        'YouTubeLearnCode', 'YouTubeLevelUpTuts', 'YouTubeMIT',
#        'YouTubeMozillaHacks', 'YouTubeOther', 'YouTubeSimplilearn',
#        'YouTubeTheNewBoston'],
#       dtype='object', length=136)

# %%
#null values
df_null_per = (df.isnull().sum()/df.shape[0])*100

# %%
df_col_use = df_null_per[df_null_per<50].index

# %%
df[df_col_use].head(3)
# Out:
#     Age  AttendedBootcamp       CityPopulation       CommuteTime  \
# 0  27.0               0.0  more than 1 million  15 to 29 minutes
# 1  34.0               0.0    less than 100,000               NaN
# 2  21.0               0.0  more than 1 million  15 to 29 minutes
#
#              CountryCitizen               CountryLive  \
# 0                    Canada                    Canada
# 1  United States of America  United States of America
# 2  United States of America  United States of America
#
#                    EmploymentStatus  Gender  HasDebt  HasFinancialDependents  \
# 0                Employed for wages  female      1.0                     0.0
# 1  Not working but looking for work    male      1.0                     0.0
# 2                Employed for wages    male      0.0                     0.0
#
#       ...             Part1EndTime       Part1StartTime         Part2EndTime  \
# 0     ...      2017-03-09 00:36:22  2017-03-09 00:32:59  2017-03-09 00:59:46
# ...

# %%
df['EmploymentStatus'].head()
# Out:
# 0                  Employed for wages
# 1    Not working but looking for work
# 2                  Employed for wages
# 3                  Employed for wages
# 4    Not working but looking for work
# Name: EmploymentStatus, dtype: object

# %%
plt.style.use('fivethirtyeight')
df['EmploymentStatus'].value_counts().sort_values(ascending=False).plot.barh(figsize=(8,6))

# %%
df_col_use
# Out:
# Index(['Age', 'AttendedBootcamp', 'CityPopulation', 'CommuteTime',
#        'CountryCitizen', 'CountryLive', 'EmploymentStatus', 'Gender',
#        'HasDebt', 'HasFinancialDependents', 'HasHighSpdInternet',
#        'HasServedInMilitary', 'HoursLearning', 'ID.x', 'ID.y',
#        'IsEthnicMinority', 'IsReceiveDisabilitiesBenefits', 'IsSoftwareDev',
#        'IsUnderEmployed', 'JobPref', 'LanguageAtHome', 'MaritalStatus',
#        'MoneyForLearning', 'MonthsProgramming', 'NetworkID', 'Part1EndTime',
#        'Part1StartTime', 'Part2EndTime', 'Part2StartTime',
#        'ResourceCodecademy', 'ResourceFCC', 'ResourceSO', 'ResourceW3S',
#        'SchoolDegree', 'SchoolMajor'],
#       dtype='object')

# %%
df['HoursLearning'].value_counts().hist()
plt.xlabel('count')
plt.ylabel('hours')
# Out:
# Text(0,0.5,'hours')

# %%
df['JobPref'].value_counts().plot.barh();

# %%
df['SchoolDegree'].value_counts().plot.barh();

# %%
df['HasDebt'].value_counts().plot.bar()
plt.xticks([0,1],['no','yes']);

# %%
df['HasFinancialDependents'].value_counts().plot.bar()
plt.xticks([0,1],['no','yes']);

# %%
df_age_dist = df['Age'].value_counts().sort_index()

# %%
r = df_age_dist.index

# %%
x = df_age_dist.values

# %%
df_age_dist.plot.bar(figsize=(12,8))

# %%
df_age_dist.plot.hist(bins=10,range=(11,73))

# %%
df['IsUnderEmployed'].value_counts()

# %%
df_count_dist = df['CountryCitizen'].value_counts()

# %%
df_count_dist[df_count_dist>20].sort_values(ascending=False).plot.barh()

# %%
df_month_dist = df['MonthsProgramming'].value_counts()

# %%
df_month_dist[df_month_dist>15].plot.bar()

# %%
df[df['MonthsProgramming']==24]['IsUnderEmployed'].value_counts()
# Out:
# 0.0    87
# 1.0    36
# Name: IsUnderEmployed, dtype: int64
